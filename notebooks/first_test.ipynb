# %%
from types.bond import BaseBond
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from types.bond import BaseBond
#
# ModuleNotFoundError: No module named 'types.bond'; 'types' is not a package
